# %% [markdown]
# **AI and Marketing:** Develop data-driven content for a given business organization (Website). Optimize Website content for search engines. Send emails to customers with personalized content/activity.

# %%
# Importing Libraries
import random

# %%
def generate_content(topic):
    intro = f"Welcome to our guide on {topic}! In this post, we will explore key insights and tips."

    headings = [
        "Introduction",
        "Why It Matters",
        "Best Practices",
        "Conclusion"
    ]

    tips = [
        "Use AI tools to analyze customer behaviour.",
        "Optimize website content for better engagement.",
        "Leverage email marketing to drive conversions.",
        "Ensure mobile responsiveness for a better user experience."
    ]

    content = f"{intro}\n\n"

    for heading in headings:
        content += f"## {heading}\n"
        content += f"- {random.choice(tips)}\n\n"

    return content

# %%
# Example Business Topic
topic = "AI in Marketing"

content = generate_content(topic)
print(content)
# Out:
# Welcome to our guide on AI in Marketing! In this post, we will explore key insights and tips.
#
# ## Introduction
# - Use AI tools to analyze customer behaviour.
#
# ## Why It Matters
# - Leverage email marketing to drive conversions.
#
# ## Best Practices
# - Use AI tools to analyze customer behaviour.
#
# ## Conclusion
# - Ensure mobile responsiveness for a better user experience.

# %%
def optimize_content(content):
    """
    Adds SEO keywords if they are missing from the content.
    """

    seo_keywords = [
        "AI Marketing",
        "SEO Optimization",
        "Digital Strategy",
        "Customer Engagement"
    ]

    for keyword in seo_keywords:
        if keyword not in content:
            content += f"\nDon't forget: {keyword} is key for success!"

    return content

optimized_content = optimize_content(content)
print(optimized_content)
# Out:
# Welcome to our guide on AI in Marketing! In this post, we will explore key insights and tips.
#
# ## Introduction
# - Use AI tools to analyze customer behaviour.
#
# ## Why It Matters
# - Leverage email marketing to drive conversions.
#
# ## Best Practices
# - Use AI tools to analyze customer behaviour.
#
# ## Conclusion
# - Ensure mobile responsiveness for a better user experience.
#
#
# Don't forget: AI Marketing is key for success!
# Don't forget: SEO Optimization is key for success!
# Don't forget: Digital Strategy is key for success!
# Don't forget: Customer Engagement is key for success!

# %%
def send_email(name, product):
    email_template = f"""
Subject: Special Offer for You, {name}!

Hi {name},

We noticed you're interested in {product}.
Here's an exclusive deal designed just for you!

Visit our website now and enjoy special discounts.

Best Regards,
Your AI Marketing Team
"""

    print(email_template)

send_email("Akriti S Shetty", "AI Business Tools")
# Out:
# Subject: Special Offer for You, Akriti S Shetty!
#
# Hi Akriti S Shetty,
#
# We noticed you're interested in AI Business Tools.
# Here's an exclusive deal designed just for you!
#
# Visit our website now and enjoy special discounts.
#
# Best Regards,
# Your AI Marketing Team
